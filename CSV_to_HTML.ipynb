# %% [markdown]
# ## Read CSV and Convert to HTML
#
# - The purpose of this notebook is to generate read our weather data from a CSV and generate an HTML table using a Pandas DataFrame.

# %%
import pandas as pd

# %%
df = pd.read_csv("Resources/weather_data.csv")
weather_df = df.drop(columns = "Unnamed: 0")
weather_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Bluff -46.6000  168.3333     47.59        75          11       20.45
# 1      Hobart -42.8794  147.3294     52.27        97         100       21.85
# 2  Rio Grande -32.0350  -52.0986     66.31        86          12        6.49
# 3        Kem'  64.9555   34.5793     53.13        68          50        6.26
# 4       Kapaa  22.0752 -159.3190     82.47        69          40       12.66
#
#   Country        Date
# 0      NZ  1660426786
# 1      AU  1660426818
# 2      BR  1660426878
# 3      RU  1660426881
# 4      US  1660426645

# %%
weather_html = weather_df.to_html()
weather_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed</th>\n      <th>Country</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Bluff</td>\n      <td>-46.6000</td>\n      <td>168.3333</td>\n      <td>47.59</td>\n      <td>75</td>\n      <td>11</td>\n      <td>20.45</td>\n      <td>NZ</td>\n      <td>1660426786</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Hobart</td>\n      <td>-42.8794</td>\n      <td>147.3294</td>\n      <td>52.27</td>\n      <td>97</td>\n      <td>100</td>\n      <td>21.85</td>\n      <td>AU</td>\n      <td>1660426818</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Rio Grande</td>\n      <td>-32.0350</td>\n      <td>-52.0986</td>\n      <td>66.31</td>\n      <td>86</td>\n      <td>12</td>\n     
# ...

# %%
weather_df.to_html("Resources/weather_data.html")
